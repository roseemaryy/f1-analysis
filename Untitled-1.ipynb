# %%
# %load_ext sql
# %sql sqlite://
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# CREATE TABLE f1 (
#     company_id INT PRIMARY KEY,
#     drivers_id INT,
#     company_name VARCHAR(40),
#     ceo_name VARCHAR(1),
#     year_create_id DATE
# );
# Out:
#  * sqlite://
#    sqlite:///f1data.db
# (sqlite3.OperationalError) table f1 already exists
# [SQL: CREATE TABLE f1 (
#     company_id INT PRIMARY KEY,
#     drivers_id INT,
#     company_name VARCHAR(40),
#     ceo_name VARCHAR(1),
#     year_create_id DATE
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# INSERT INTO f1 (company_id, drivers_id, company_name, ceo_name, year_create_id)
# VALUES
#     (5, 105, "Aston Martin", "L", "1959-01-01"),
#     (6, 106, "Williams", "J", "1977-01-01"),
#     (7, 107, "Alpine", "O", "1976-01-01"),
#     (8, 108, "Stake", "S", "1993-01-01"),
#     (9, 109, "RB", "C", "2006-01-01"),
#     (10, 110, "Haas", "G", "2016-01-01");
# Out:
#  * sqlite://
#    sqlite:///f1data.db
# (sqlite3.IntegrityError) UNIQUE constraint failed: f1.company_id
# [SQL: INSERT INTO f1 (company_id, drivers_id, company_name, ceo_name, year_create_id)
# VALUES
#     (5, 105, "Aston Martin", "L", "1959-01-01"),
#     (6, 106, "Williams", "J", "1977-01-01"),
#     (7, 107, "Alpine", "O", "1976-01-01"),
#     (8, 108, "Stake", "S", "1993-01-01"),
#     (9, 109, "RB", "C", "2006-01-01"),
#     (10, 110, "Haas", "G", "2016-01-01");]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# CREATE TABLE drivers (
#     drivers_id INT PRIMARY KEY,
#     team_id VARCHAR(30),
#     age INT,
#     first_name VARCHAR(20),
#     last_name VARCHAR(20),
#     sex VARCHAR(10),
#     salary INT
# );
# Out:
#  * sqlite://
#    sqlite:///f1data.db
# (sqlite3.OperationalError) table drivers already exists
# [SQL: CREATE TABLE drivers (
#     drivers_id INT PRIMARY KEY,
#     team_id VARCHAR(30),
#     age INT,
#     first_name VARCHAR(20),
#     last_name VARCHAR(20),
#     sex VARCHAR(10),
#     salary INT
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# INSERT INTO drivers (drivers_id, team_id, age, first_name, last_name, sex, salary)
# VALUES
#     (101, "McLaren", 24, "Lando", "Norris", "M", 18000000),
#     (102, "Ferrari", 26, "Charles", "Leclerc", "M", 12000000),
#     (103, "Mercedes", 39, "Lewis", "Hamilton", "M", 35000000),
#     (104, "Red Bull", 26, "Max", "Verstappen", "M", 50000000),
#     (105, "Aston Martin", 42, "Fernando", "Alonso", "M", 20000000),
#     (106, "Williams", 23, "Logan", "Sargeant", "M", 1000000),
#     (107, "Alpine", 27, "Esteban", "Ocon", "M", 5000000),
#     (108, "Stake", 25, "Zhou", "Guanyu", "M", 3000000),
#     (109, "RB", 22, "Yuki", "Tsunoda", "M", 2000000),
#     (110, "Haas", 24, "Kevin", "Magnussen", "M", 2000000);
# Out:
#  * sqlite://
#    sqlite:///f1data.db
# 10 rows affected.
# []

# %%
pip install ipython-sql prettytable --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('sqlite:///f1data.db')

df_f1 = pd.read_sql("SELECT * FROM f1", engine)
df_f1
# Out:
#    company_id  drivers_id  company_name ceo_name year_create_id
# 0           1         101       McLaren        Z     1963-01-01
# 1           2         102       Ferrari        B     1929-11-16
# 2           3         103      Mercedes        T     1954-07-04
# 3           4         104      Red Bull        H     2005-01-01
# 4           5         105  Aston Martin        L     1959-01-01
# 5           6         106      Williams        J     1977-01-01
# 6           7         107        Alpine        O     1976-01-01
# 7           8         108         Stake        S     1993-01-01
# 8           9         109            RB        C     2006-01-01
# 9          10         110          Haas        G     2016-01-01

# %%
from sqlalchemy import inspect

inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['f1']

# %%
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", con=engine)
print(tables)
# Out:
#   name
# 0   f1

# %%
import os
os.listdir("/Users/RoseKamau/Downloads/archive (3)")
# Out:
# ['circuits.csv',
#  'status.csv',
#  'lap_times.csv',
#  'sprint_results.csv',
#  'drivers.csv',
#  'races.csv',
#  'constructors.csv',
#  'constructor_standings.csv',
#  'qualifying.csv',
#  'driver_standings.csv',
#  'constructor_results.csv',
#  'pit_stops.csv',
#  'seasons.csv',
#  'results.csv']

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/circuits.csv")

# %%
df.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/constructor_results.csv")

# %%
df.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0     \N
# 1                     2      18              2     8.0     \N
# 2                     3      18              3     9.0     \N
# 3                     4      18              4     5.0     \N
# 4                     5      18              5     2.0     \N

# %%
df.dropna()
# Out:
#        constructorResultsId  raceId  constructorId  points status
# 0                         1      18              1    14.0     \N
# 1                         2      18              2     8.0     \N
# 2                         3      18              3     9.0     \N
# 3                         4      18              4     5.0     \N
# 4                         5      18              5     2.0     \N
# ...                     ...     ...            ...     ...    ...
# 12620                 17125    1144            210     4.0     \N
# 12621                 17126    1144            117     2.0     \N
# 12622                 17127    1144              3     0.0     \N
# 12623                 17128    1144            215     0.0     \N
# 12624                 17129    1144             15     0.0     \N
#
# [12625 rows x 5 columns]

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/constructor_standings.csv")

# %%
df.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins
# 0            1     1
# 1            3     0
# 2            2     0
# 3            4     0
# 4            5     0

# %%
df =pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/constructors.csv")
df.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/driver_standings.csv")
df.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/drivers.csv")
df.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
df.dropna()
# Out:
#      driverId   driverRef number code  forename     surname         dob  \
# 0           1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...         ...    ...  ...       ...         ...         ...
# 856       858    sargeant      2  SAR     Logan    Sargeant  2000-12-31
# 857       859      lawson     30  LAW      Liam      Lawson  2002-02-11
# 858       860     bearman     38  BEA    Oliver     Bearman  2005-05-08
# 859       861   colapinto     43  COL    Franco   Colapinto  2003-05-27
# 860       862      doohan     61  DOO      Jack      Doohan  2003-01-20
#
#        nationality                                             url
# ...

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/lap_times.csv")
df.head()
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/pit_stops.csv")
df.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/qualifying.csv")
df.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/races.csv")
df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# ...

# %%
df.dropna()
# Out:
#       raceId  year  round  circuitId                    name        date  \
# 0          1  2009      1          1   Australian Grand Prix  2009-03-29
# 1          2  2009      2          2    Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17      Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3      Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4      Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                     ...         ...
# 1120    1140  2024     20         32  Mexico City Grand Prix  2024-10-27
# 1121    1141  2024     21         18    São Paulo Grand Prix  2024-11-03
# 1122    1142  2024     22         80    Las Vegas Grand Prix  2024-11-23
# 1123    1143  2024     23         78        Qatar Grand Prix  2024-12-01
# 1124    1144  2024     24         24    Abu Dhabi Grand Prix  2024-12-08
#
#           time                                                url    fp1_date  \
# ...

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/results.csv")
df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
df.dropna()
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26754     26760    1144       825            210     20    14       16
# 26755     26761    1144       859            215     30    12       17
# 26756     26762    1144       822             15     77     9       \N
# 26757     26763    1144       861              3     43    20       \N
# 26758     26764    1144       815              9     11    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/seasons.csv")
df.head()
# Out:
#    year                                                url
# 0  2009  http://en.wikipedia.org/wiki/2009_Formula_One_...
# 1  2008  http://en.wikipedia.org/wiki/2008_Formula_One_...
# 2  2007  http://en.wikipedia.org/wiki/2007_Formula_One_...
# 3  2006  http://en.wikipedia.org/wiki/2006_Formula_One_...
# 4  2005  http://en.wikipedia.org/wiki/2005_Formula_One_...

# %%
df.dropna()
# Out:
#     year                                                url
# 0   2009  http://en.wikipedia.org/wiki/2009_Formula_One_...
# 1   2008  http://en.wikipedia.org/wiki/2008_Formula_One_...
# 2   2007  http://en.wikipedia.org/wiki/2007_Formula_One_...
# 3   2006  http://en.wikipedia.org/wiki/2006_Formula_One_...
# 4   2005  http://en.wikipedia.org/wiki/2005_Formula_One_...
# ..   ...                                                ...
# 70  2020  http://en.wikipedia.org/wiki/2020_Formula_One_...
# 71  2021  http://en.wikipedia.org/wiki/2021_Formula_One_...
# 72  2022  http://en.wikipedia.org/wiki/2022_Formula_One_...
# 73  2023  http://en.wikipedia.org/wiki/2023_Formula_One_...
# 74  2024  https://en.wikipedia.org/wiki/2024_Formula_One...
#
# [75 rows x 2 columns]

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/sprint_results.csv")
df.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid position  \
# 0         1    1061       830              9      33     2        1
# 1         2    1061         1            131      44     1        2
# 2         3    1061       822            131      77     3        3
# 3         4    1061       844              6      16     4        4
# 4         5    1061       846              1       4     6        5
#
#   positionText  positionOrder  points  laps       time milliseconds  \
# 0            1              1       3    17  25:38.426      1538426
# 1            2              2       2    17     +1.430      1539856
# 2            3              3       1    17     +7.502      1545928
# 3            4              4       0    17    +11.278      1549704
# 4            5              5       0    17    +24.111      1562537
#
#   fastestLap fastestLapTime  statusId
# 0         14       1:30.013         1
# 1         17       1:29.937         1
# ...

# %%
df.dropna()
# Out:
#      resultId  raceId  driverId  constructorId  number  grid position  \
# 0           1    1061       830              9      33     2        1
# 1           2    1061         1            131      44     1        2
# 2           3    1061       822            131      77     3        3
# 3           4    1061       844              6      16     4        4
# 4           5    1061       846              1       4     6        5
# ..        ...     ...       ...            ...     ...   ...      ...
# 355       356    1143       859            215      30    10       16
# 356       357    1143       852            215      22    16       17
# 357       358    1143       861              3      43     0       18
# 358       359    1143       855             15      24    18       19
# 359       360    1143       815              9      11     0       20
#
#     positionText  positionOrder  points  laps       time milliseconds  \
# ...

# %%
df = pd.read_csv("/Users/RoseKamau/Downloads/archive (3)/status.csv")
df.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
df.dropna()
# Out:
#      statusId          status
# 0           1        Finished
# 1           2    Disqualified
# 2           3        Accident
# 3           4       Collision
# 4           5          Engine
# ..        ...             ...
# 134       137          Damage
# 135       138          Debris
# 136       139         Illness
# 137       140       Undertray
# 138       141  Cooling system
#
# [139 rows x 2 columns]

# %%
df. describe()
# Out:
#          statusId
# count  139.000000
# mean    71.237410
# std     41.092434
# min      1.000000
# 25%     35.500000
# 50%     72.000000
# 75%    106.500000
# max    141.000000

# %%
print(df.columns)
# Out:
# Index(['statusId', 'status'], dtype='object')

# %%
df['statusId'].value_counts()
# Out:
# statusId
# 1      1
# 96     1
# 90     1
# 91     1
# 92     1
#       ..
# 41     1
# 40     1
# 39     1
# 38     1
# 141    1
# Name: count, Length: 139, dtype: int64

# %%
df.dropna()
# Out:
#      statusId          status
# 0           1        Finished
# 1           2    Disqualified
# 2           3        Accident
# 3           4       Collision
# 4           5          Engine
# ..        ...             ...
# 134       137          Damage
# 135       138          Debris
# 136       139         Illness
# 137       140       Undertray
# 138       141  Cooling system
#
# [139 rows x 2 columns]

# %%
df['2xstatusId'] = df['statusId'] * 2

# %%
df
# Out:
#      statusId          status  2xstatusId
# 0           1        Finished           2
# 1           2    Disqualified           4
# 2           3        Accident           6
# 3           4       Collision           8
# 4           5          Engine          10
# ..        ...             ...         ...
# 134       137          Damage         274
# 135       138          Debris         276
# 136       139         Illness         278
# 137       140       Undertray         280
# 138       141  Cooling system         282
#
# [139 rows x 3 columns]

# %%
df['statusId'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# Name: statusId, Length: 139, dtype: bool

# %%
print(df.columns)
# Out:
# Index(['statusId', 'status', '2xstatusId'], dtype='object')

# %%
df3 = df.value_counts('statusId')

# %%
df3.plot()
# Out:
# <Axes: xlabel='statusId'>
